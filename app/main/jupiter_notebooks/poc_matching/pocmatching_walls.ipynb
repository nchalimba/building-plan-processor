# %% [markdown]
# ### Importsetup

# %%
###########################################################################
from app.main.extraction.dxf_extraction_coordinator import DxfExtractionCoordinator
from app.main.models.wall import Wall 
from app.main.models.architecture_wall import Architectur_Wall
from app.main.models.point import Point 
from app.main.services.walls_extraction import WallsExtraction
from app.main.services.dxf_extraction_simple import DxfExtractionSimple
from app.main.dtos.request.extraction_request_file import ExtractionRequestFile
from app.main.models.line import Line 

###########################################################################
from shapely.geometry.polygon import LinearRing
from shapely.geometry.polygon import Polygon as shapePolygon
from shapely.geometry import Point as shapePoint
from shapely.geometry import LineString
import math
import numpy as np
import itertools as it
from scipy.spatial.distance import cdist
import ezdxf
import uuid
import statistics
import matplotlib.pyplot as plt
import operator

###########################################################################
file_path_simple = '../../media/Einfache_Plaene_Compass/'
file_path_architecture = '../../media/Architektenplaene/'
###########################################################################
file_name_simple = 'R-Bau_D_EG.dxf'
file_name_architecutre = 'R-Bau_A_EG.dxf'
###########################################################################
simple_dxf = ezdxf.readfile(file_path_simple+file_name_simple)
architecture_dxf = ezdxf.readfile(file_path_architecture+file_name_architecutre)
simple_model = simple_dxf.modelspace()
arichtecture_model = architecture_dxf.modelspace()

# %%
# DATA-PREPARATION
################ For Matching
dxf_file = ezdxf.readfile(file_path_simple + file_name_simple)
dxf_extraction_simple = DxfExtractionSimple()
################ For Matching
simple_polygons, polygons_with_virtual_entities, extracted_functionalities = dxf_extraction_simple.get_all_polygons(dxf_file ,file_path_simple + file_name_simple)
############################################### For Scaling
simple_polylines_for_scale = simple_model.query("LWPolyline[layer=='RAUMPOLYGON']")

# %% [markdown]
# ## Helper-Methods

# %%
''' This Method gets ezdxf objects from an layer and an entity.'''
def get_polylines_by_layer(layer, entity):
    query_string = f"{entity}[layer=='{layer}']"
    polylines = arichtecture_model.query(query_string)
    polylines_list = []
    for x in polylines:
        polylines_list.append(x)
    return polylines_list, layer

''' This method creates a list of polylines for matching walls'''
def create_architecture_polygons():
    leichtwand_polylines = arichtecture_model.query("LWPolyline[layer=='A_02_LEICHTWAND']")
    tragwand_polylines = arichtecture_model.query("LWPolyline[layer=='A_01_TRAGWAND']")
    architecture_polylines = []
    for x in leichtwand_polylines:
        architecture_polylines.append(x)
    for x in tragwand_polylines:
        architecture_polylines.append(x)
    return architecture_polylines

''' This method plots the all polylines in an dxf-file. '''
def create_dxf_file(simple_polylines: list, architecture_polylines: list):
    doc = ezdxf.new('R2000')
    msp = doc.modelspace()
    for x in simple_polylines:
        msp.add_lwpolyline(x)
    for x in architecture_polylines:
        msp.add_lwpolyline(x)
    doc.saveas("dataForMatching.dxf")


''' This method creates from an Polyline an list of coordinates. '''
def create_coordinates_list(simple_polylines: list):
    coordinates = []
    for x in simple_polylines:
        for y in x:
            coordinates.append(y)
    return coordinates

''' This method finds each min/max x-value of an coordinates tuple.'''
def filter_coordinates(simple_polylines: list, filter_aim):
    coordinates = create_coordinates_list(simple_polylines) 
    if filter_aim == 'MIN':
        item=min(coordinates, key=lambda n: n[0])
        return item
    if filter_aim == 'MAX':
        item=max(coordinates, key=lambda n: n[0])
        return item

''' This method checks if the plans can be matched or not.'''
def check_scaling(architecture_polygons: list, simple_polygons: list):
    boolhandler = False

    min_value_simple = filter_coordinates(simple_polygons, 'MIN')
    max_value_simple = filter_coordinates(simple_polygons, 'MAX')

    point_min_simple = shapePoint(min_value_simple[0], min_value_simple[1])
    point_max_simple = shapePoint(max_value_simple[0], max_value_simple[1])

    distance_simple = point_min_simple.distance(point_max_simple)

    min_value_architecture = filter_coordinates(architecture_polygons, 'MIN')
    max_value_architecture = filter_coordinates(architecture_polygons, 'MAX')

    point_min_architecture = shapePoint(min_value_architecture[0], min_value_architecture[1])
    point_max_architecture = shapePoint(max_value_architecture[0], max_value_architecture[1])

    distance_architecture = point_min_architecture.distance(point_max_architecture)

    factor = distance_simple/distance_architecture
    #print(factor)
    if( 0.95 <= factor <= 1.05):
        boolhandler = True

    return boolhandler

'''This method creates multiple Linestrings from an Polyline with each two coordinate Points.'''
def create_linestring_from_polyline(polyline):
    linestring_list = []
    xy_coordinates_list = []
    index = 0
    #linestring braucht koordianten in xy-format
    for x in polyline:
        x_value = x[0]
        y_value = x[1]
        coordinate = (x_value, y_value)
        xy_coordinates_list.append(coordinate)
    for index in range(len(xy_coordinates_list)-1):
        line = LineString([xy_coordinates_list[index] , xy_coordinates_list[index+1]])
        linestring_list.append(line)
    return linestring_list

''' This method creates a shapely linestring from an wall object.'''
def create_linestring_from_wall(wall):
    line = LineString([(wall.start_point.x_coordinate, wall.start_point.y_coordinate),(wall.end_point.x_coordinate, wall.end_point.y_coordinate)])
    return line

''' This method gets the wallthickness from an architechture_line object from the total architecture wall list.''' 
def get_wall_thickness(architechture_line, architecture_wall_list):
    wall_thickness = 0.0
    for x in architecture_wall_list:
        if(x.id == architechture_line.id_wall):
            wall_thickness = x.wall_thickness
            return wall_thickness, x

''' This method gets the shortes line (wall) from an polyline from the layer "leichtwand" and "tragwand", which are the wallthickness an calculates the average.'''
def calculate_wallthickness(polyline):
    #print(type(polyline))
    wallthickness = 0.0
    linestring_list = create_linestring_from_polyline(polyline)
    list_avg = []
    #print(len(linestring_list))
    for x in linestring_list:
        #print(x.length)
        if(x.length < 0.22):
            list_avg.append(x.length)
    if(len(list_avg) < 1):
        wallthickness = 0.25
        return wallthickness        
    else:
        wallthickness = statistics.mean(list_avg)
        return wallthickness

''' This method get empirical the average Wallthickness from all polylines from one layer. '''
def calculate_avg_value(polyline):
    list_with_min_lenghts = []

    for x in polyline:
        linestring_list = create_linestring_from_polyline(x)
        lenghts = []
        for y in linestring_list:
            lenghts.append(y.length)
        
        min_value = min(lenghts)
        list_with_min_lenghts.append(min_value)
    return round(statistics.mean(list_with_min_lenghts), 2)

simple_walls = WallsExtraction.generete_walls_new(create_coordinates_list(simple_polylines_for_scale))
architecture_polylines_for_scale = create_architecture_polygons()
create_dxf_file(simple_polylines_for_scale, architecture_polylines_for_scale)
######################################## For Matching
architecture_polylines1, layer1 = get_polylines_by_layer('A_02_LEICHTWAND', 'LWPolyline')
architecture_polylines2, layer2 = get_polylines_by_layer('A_01_TRAGWAND', 'LWPolyline')
#######################################
# Out:
# 2581 | endPoint: 0.6222028531699522/-0.7163082033292076)
# 2021-06-10 20:00:09.381 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: 5.165574672456614/24.43274102032204 | endPoint: 5.024823018490039/24.43274102032204)
# 2021-06-10 20:00:09.403 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: 5.024823018490039/24.50774102032204 | endPoint: 0.5692860184900326/24.50774102032204)
# 2021-06-10 20:00:09.416 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 168.53011980323782 - for walll (startPoint: 0.5692860184900326/24.50774102032204 | endPoint: -0.5194585033157324/23.26989896542915)
# 2021-06-10 20:00:09.459 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319127 - for walll (startPoint: -0.5194585033157324/23.26989896542914 | endPoint: -4.430811459704202/23.26989896542916)
# 2021-06-10 20:00:09.473 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 265.8636047431437 - for walll (startPoint: -4.430811459704202/23.26989896542916 | endPoint: -5.519555981509967/24.50774102032204)
# 2021-06-10 20:00:09.490 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: -5.519555981509967/24.50774102032204 | endPoint: -6.17513498150997/24.50774102032204)
# 2021-06-10 20:00:09.515 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: -6.17513498150997/24.43274102032204 | endPoint: -31.20013498150996/24.43274102032204)
# 2021-06-10 20:00:09.559 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.1968635918137 - for walll (startPoint: -37.57613498150998/25.35774084371025 | endPoint: -45.25013498150996/25.35774102032205)
# 2021-06-10 20:00:09.680 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.39979207223897 - for walll (startPoint: -84.50013398150996/25.35774102032204 | endPoint: -92.97038431484332/25.38774102032204)
# 2021-06-10 20:00:09.752 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 99.19616687757603 - for walll (startPoint: -107.17384298151/24.43274102032204 | endPoint: -107.21638098151/24.51274102032204)
# 2021-06-10 20:00:09.763 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 37.19686227319095 - for walll (startPoint: -107.21638098151/24.51274102032204 | endPoint: -107.25035598151/24.51274102032204)
# 2021-06-10 20:00:09.778 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 99.19776220360919 - for walll (startPoint: -107.25035598151/24.51274102032204 | endPoint: -103.9674006186597/18.33816602275141)
# 2021-06-10 20:00:09.834 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 99.19687542070415 - for walll (startPoint: -94.05808598150996/-0.2983209796779605 | endPoint: -92.13533662583562/-3.914488580943384)
# 2021-06-10 20:00:09.835 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 78.46 %
# 2021-06-10 20:00:09.913 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 78.86 %
# 2021-06-10 20:00:10.113 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 79.27 %
# 2021-06-10 20:00:10.389 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 79.67 %
# 2021-06-10 20:00:10.496 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 80.08 %
# 2021-06-10 20:00:10.841 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 80.49 %
# 2021-06-10 20:00:10.933 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 80.89 %
# 2021-06-10 20:00:11.000 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 81.3 %
# 2021-06-10 20:00:11.069 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 81.71 %
# 2021-06-10 20:00:11.455 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 82.11 %
# 2021-06-10 20:00:11.519 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 82.52 %
# 2021-06-10 20:00:11.889 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 82.93 %
# 2021-06-10 20:00:11.964 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 83.33 %
# 2021-06-10 20:00:12.030 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 83.74 %
# 2021-06-10 20:00:12.114 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 84.15 %
# 2021-06-10 20:00:12.219 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 84.55 %
# 2021-06-10 20:00:12.289 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 84.96 %
# 2021-06-10 20:00:12.358 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 85.37 %
# 2021-06-10 20:00:12.590 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 85.77 %
# 2021-06-10 20:00:12.658 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 86.18 %
# 2021-06-10 20:00:12.725 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 86.59 %
# 2021-06-10 20:00:13.039 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 86.99 %
# 2021-06-10 20:00:13.179 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 29.450274760607684 - for walll (startPoint: -67.55467901477934/-16.01088761352031 | endPoint: -76.32103756133853/-17.20340486806151)
# 2021-06-10 20:00:13.329 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 29.450274760607684 - for walll (startPoint: -67.55467901477934/-16.01088761352031 | endPoint: -76.32103756133853/-17.20340486806151)
# 2021-06-10 20:00:13.348 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 87.4 %
# 2021-06-10 20:00:13.448 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 31.632616342568003 - for walll (startPoint: -57.17906969414778/-14.99700910276013 | endPoint: -67.40588069075498/-15.99331392886569)
# 2021-06-10 20:00:13.589 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 31.632616342568003 - for walll (startPoint: -57.17906969414778/-14.99700910276013 | endPoint: -67.40588069075498/-15.99331392886569)
# 2021-06-10 20:00:13.608 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 87.8 %
# 2021-06-10 20:00:13.708 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 33.230554015732544 - for walll (startPoint: -57.02933382012885/-14.98550650505226 | endPoint: -53.40358698150997/-14.73411197967796)
# 2021-06-10 20:00:13.752 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 34.40016284603923 - for walll (startPoint: -53.00432613129413/-14.70980729058294 | endPoint: -47.0004431112588/-14.41651510788094)
# 2021-06-10 20:00:13.848 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 33.230554015732544 - for walll (startPoint: -57.02933382012885/-14.98550650505226 | endPoint: -53.40358698150997/-14.73411197967796)
# 2021-06-10 20:00:13.898 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 34.40016284603923 - for walll (startPoint: -53.00432613129413/-14.70980729058294 | endPoint: -47.0004431112588/-14.41651510788094)
# 2021-06-10 20:00:13.926 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 88.21 %
# 2021-06-10 20:00:14.008 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 36.306007487207886 - for walll (startPoint: -36.36313498150997/-14.24225897967796 | endPoint: -46.57077407331779/-14.40098370734004)
# 2021-06-10 20:00:14.096 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 36.306007487207886 - for walll (startPoint: -36.36313498150997/-14.24225897967796 | endPoint: -46.57077407331779/-14.40098370734004)
# 2021-06-10 20:00:14.117 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 88.62 %
# 2021-06-10 20:00:14.156 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 37.19686227319095 - for walll (startPoint: -31.15013498150996/-14.21225897967796 | endPoint: -31.13813498150996/-14.21225897967796)
# 2021-06-10 20:00:14.180 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 37.19686227319095 - for walll (startPoint: -31.13813498150996/-14.24225897967795 | endPoint: -36.18713498150997/-14.24225897967795)
# 2021-06-10 20:00:14.220 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 37.19686227319095 - for walll (startPoint: -31.15013498150996/-14.21225897967796 | endPoint: -31.13813498150996/-14.21225897967796)
# 2021-06-10 20:00:14.241 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 37.19686227319095 - for walll (startPoint: -31.13813498150996/-14.24225897967795 | endPoint: -36.18713498150997/-14.24225897967795)
# 2021-06-10 20:00:14.242 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 89.02 %
# 2021-06-10 20:00:14.280 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 282.7770177731915 - for walll (startPoint: -44.6084213511014/0.7377410661366355 | endPoint: -43.04799909906966/-2.699026170330105)
# 2021-06-10 20:00:14.326 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 151.61671577319115 - for walll (startPoint: -39.90226969080145/-2.699026637008455 | endPoint: -38.34184660057393/0.7377410114504528)
# 2021-06-10 20:00:14.490 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 127.19686227319096 - for walll (startPoint: -36.18713498150997/-11.58725897967795 | endPoint: -36.18713498150997/-6.961258979677957)
# 2021-06-10 20:00:14.632 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 282.7770177731915 - for walll (startPoint: -44.6084213511014/0.7377410661366355 | endPoint: -43.04799909906966/-2.699026170330105)
# 2021-06-10 20:00:14.670 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 151.61671577319115 - for walll (startPoint: -39.90226969080145/-2.699026637008455 | endPoint: -38.34184660057393/0.7377410114504528)
# 2021-06-10 20:00:14.828 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 127.19686227319096 - for walll (startPoint: -36.18713498150997/-11.58725897967795 | endPoint: -36.18713498150997/-6.961258979677957)
# 2021-06-10 20:00:14.953 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 89.43 %
# 2021-06-10 20:00:15.131 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 89.84 %
# 2021-06-10 20:00:15.354 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 90.24 %
# 2021-06-10 20:00:15.645 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 90.65 %
# 2021-06-10 20:00:15.708 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 91.06 %
# 2021-06-10 20:00:15.777 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 91.46 %
# 2021-06-10 20:00:15.871 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 91.87 %
# 2021-06-10 20:00:15.987 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 92.28 %
# 2021-06-10 20:00:16.021 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 115.5002088048643 - for walll (startPoint: -109.5292081442461/6.4328448810237 | endPoint: -109.5789537516003/6.673128008376977)
# 2021-06-10 20:00:16.118 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 186.5109777937923 - for walll (startPoint: -105.0206467578607/17.37250407225313 | endPoint: -103.9188137617458/18.02635753489954)
# 2021-06-10 20:00:16.235 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 115.5002088048643 - for walll (startPoint: -109.5292081442461/6.4328448810237 | endPoint: -109.5789537516003/6.673128008376977)
# 2021-06-10 20:00:16.305 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 186.5109777937923 - for walll (startPoint: -105.0206467578607/17.37250407225313 | endPoint: -103.9188137617458/18.02635753489954)
# 2021-06-10 20:00:16.397 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 92.68 %
# 2021-06-10 20:00:16.517 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 93.09 %
# 2021-06-10 20:00:16.566 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 93.5 %
# 2021-06-10 20:00:16.615 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 93.9 %
# 2021-06-10 20:00:16.699 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 94.31 %
# 2021-06-10 20:00:16.769 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 23.770518508190325 - for walll (startPoint: -94.53226898150997/-0.1877149796779563 | endPoint: -99.14103456856597/-1.287917371756706)
# 2021-06-10 20:00:16.781 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 43.97944828731561 - for walll (startPoint: -99.14103456856597/-1.287917371756706 | endPoint: -102.2571177281866/-0.9173074579906917)
# 2021-06-10 20:00:16.792 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 52.94109296251404 - for walll (startPoint: -102.2571177281866/-0.9173074579906917 | endPoint: -102.5456451649422/-0.8359656677825598)
# 2021-06-10 20:00:16.891 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 23.770518508190325 - for walll (startPoint: -94.53226898150997/-0.1877149796779563 | endPoint: -99.14103456856597/-1.287917371756706)
# 2021-06-10 20:00:16.899 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 43.97944828731561 - for walll (startPoint: -99.14103456856597/-1.287917371756706 | endPoint: -102.2571177281866/-0.9173074579906917)
# 2021-06-10 20:00:16.899 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 52.94109296251404 - for walll (startPoint: -102.2571177281866/-0.9173074579906917 | endPoint: -102.5456451649422/-0.8359656677825598)
# 2021-06-10 20:00:16.957 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 94.72 %
# 2021-06-10 20:00:16.977 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: 5.217334153355287/24.43274102032204 | endPoint: 7.027032719856308/24.43274102032204)
# 2021-06-10 20:00:16.999 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 202.2059557351845 - for walll (startPoint: 7.541992126732116/22.51088460580456 | endPoint: 7.474069847982708/22.49269643954646)
# 2021-06-10 20:00:17.025 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 202.19687527319076 - for walll (startPoint: 7.512872591842454/22.34779063940781 | endPoint: 10.81555537301142/23.23274102032205)
# 2021-06-10 20:00:17.050 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 202.19687527319093 - for walll (startPoint: 10.81555537301142/23.38803243794251 | endPoint: 10.21555537301142/23.22726306839361)
# 2021-06-10 20:00:17.074 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: 10.21555537301142/24.43274102032204 | endPoint: 11.98782301849003/24.43274102032204)
# 2021-06-10 20:00:17.087 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 307.19686227319096 - for walll (startPoint: 11.98782301849003/24.43274102032204 | endPoint: 11.98782301849003/22.03941808931705)
# 2021-06-10 20:00:17.108 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: 5.217334153355287/24.43274102032204 | endPoint: 7.027032719856308/24.43274102032204)
# 2021-06-10 20:00:17.132 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 202.2059557351845 - for walll (startPoint: 7.541992126732116/22.51088460580456 | endPoint: 7.474069847982708/22.49269643954646)
# 2021-06-10 20:00:17.161 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 202.19687527319076 - for walll (startPoint: 7.512872591842454/22.34779063940781 | endPoint: 10.81555537301142/23.23274102032205)
# 2021-06-10 20:00:17.195 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 202.19687527319093 - for walll (startPoint: 10.81555537301142/23.38803243794251 | endPoint: 10.21555537301142/23.22726306839361)
# 2021-06-10 20:00:17.244 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: 10.21555537301142/24.43274102032204 | endPoint: 11.98782301849003/24.43274102032204)
# 2021-06-10 20:00:17.260 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 307.19686227319096 - for walll (startPoint: 11.98782301849003/24.43274102032204 | endPoint: 11.98782301849003/22.03941808931705)
# 2021-06-10 20:00:17.275 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 95.12 %
# 2021-06-10 20:00:17.295 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: 7.18231754516206/24.43274102032204 | endPoint: 10.06555537301142/24.43274102032204)
# 2021-06-10 20:00:17.321 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 202.2059557351906 - for walll (startPoint: 10.06555537301142/23.18707072600638 | endPoint: 7.686475462848812/22.55000286338406)
# 2021-06-10 20:00:17.351 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: 7.18231754516206/24.43274102032204 | endPoint: 10.06555537301142/24.43274102032204)
# 2021-06-10 20:00:17.378 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 202.2059557351906 - for walll (startPoint: 10.06555537301142/23.18707072600638 | endPoint: 7.686475462848812/22.55000286338406)
# 2021-06-10 20:00:17.378 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 95.53 %
# 2021-06-10 20:00:17.402 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: 12.03782301849003/24.43274102032204 | endPoint: 13.73172201849004/24.43274102032204)
# 2021-06-10 20:00:17.413 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 297.19685645403354 - for walll (startPoint: 13.73172201849004/24.43274102032204 | endPoint: 15.54960103922052/14.12304290275339)
# 2021-06-10 20:00:17.488 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: 12.03782301849003/24.43274102032204 | endPoint: 13.73172201849004/24.43274102032204)
# 2021-06-10 20:00:17.499 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 297.19685645403354 - for walll (startPoint: 13.73172201849004/24.43274102032204 | endPoint: 15.54960103922052/14.12304290275339)
# 2021-06-10 20:00:17.571 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 95.93 %
# 2021-06-10 20:00:17.590 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: -165.2053325542416/97.80686161535081 | endPoint: -155.3053315542416/97.80686161535081)
# 2021-06-10 20:00:17.604 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 307.19686227319096 - for walll (startPoint: -155.3053315542416/97.80686161535081 | endPoint: -155.3053315542416/95.90685961535081)
# 2021-06-10 20:00:17.612 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 37.19686227319095 - for walll (startPoint: -155.3053315542416/95.90685961535081 | endPoint: -165.2053325542416/95.90685961535081)
# 2021-06-10 20:00:17.629 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: -165.2053325542416/97.80686161535081 | endPoint: -155.3053315542416/97.80686161535081)
# 2021-06-10 20:00:17.646 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 307.19686227319096 - for walll (startPoint: -155.3053315542416/97.80686161535081 | endPoint: -155.3053315542416/95.90685961535081)
# 2021-06-10 20:00:17.660 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 37.19686227319095 - for walll (startPoint: -155.3053315542416/95.90685961535081 | endPoint: -165.2053325542416/95.90685961535081)
# 2021-06-10 20:00:17.661 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 96.34 %
# 2021-06-10 20:00:17.681 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 194.9176747458236 - for walll (startPoint: -139.78394098151/-23.30404197967794 | endPoint: -138.67348998151/-22.84908397967795)
# 2021-06-10 20:00:17.695 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 104.91852076464541 - for walll (startPoint: -138.67348998151/-22.84908397967795 | endPoint: -136.4083505875603/-28.37801671255461)
# 2021-06-10 20:00:17.709 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 14.918359048889833 - for walll (startPoint: -136.4083505875603/-28.37801671255461 | endPoint: -138.44795098151/-29.21362397967795)
# 2021-06-10 20:00:17.724 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 194.9176747458236 - for walll (startPoint: -139.78394098151/-23.30404197967794 | endPoint: -138.67348998151/-22.84908397967795)
# 2021-06-10 20:00:17.736 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 104.91852076464541 - for walll (startPoint: -138.67348998151/-22.84908397967795 | endPoint: -136.4083505875603/-28.37801671255461)
# 2021-06-10 20:00:17.753 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 14.918359048889833 - for walll (startPoint: -136.4083505875603/-28.37801671255461 | endPoint: -138.44795098151/-29.21362397967795)
# 2021-06-10 20:00:17.754 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 96.75 %
# 2021-06-10 20:00:17.774 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: -155.16512898151/28.56133574809538 | endPoint: -154.6751378468805/28.56133574809538)
# 2021-06-10 20:00:17.789 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 307.19686227319096 - for walll (startPoint: -154.6751378468805/28.56133574809538 | endPoint: -154.6751378468805/25.03774902032205)
# 2021-06-10 20:00:17.812 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: -155.16512898151/28.56133574809538 | endPoint: -154.6751378468805/28.56133574809538)
# 2021-06-10 20:00:17.824 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 307.19686227319096 - for walll (startPoint: -154.6751378468805/28.56133574809538 | endPoint: -154.6751378468805/25.03774902032205)
# 2021-06-10 20:00:17.836 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 97.15 %
# 2021-06-10 20:00:17.982 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 97.56 %
# 2021-06-10 20:00:17.999 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: -71.06513398150996/41.62774102032205 | endPoint: -71.39513398150997/41.62774102032205)
# 2021-06-10 20:00:18.040 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: -71.39513398150997/40.58774102032204 | endPoint: -36.30013498150997/40.58774102032204)
# 2021-06-10 20:00:18.052 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 307.19686227319096 - for walll (startPoint: -36.30013498150997/40.58774102032204 | endPoint: -36.30013498150997/41.85274102032204)
# 2021-06-10 20:00:18.070 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.17214095393098 - for walll (startPoint: -36.30013498150997/41.85274102032204 | endPoint: -71.06513398150996/41.83774102032204)
# 2021-06-10 20:00:18.094 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: -71.06513398150996/41.62774102032205 | endPoint: -71.39513398150997/41.62774102032205)
# 2021-06-10 20:00:18.119 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: -71.39513398150997/40.58774102032204 | endPoint: -36.30013498150997/40.58774102032204)
# 2021-06-10 20:00:18.130 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 307.19686227319096 - for walll (startPoint: -36.30013498150997/40.58774102032204 | endPoint: -36.30013498150997/41.85274102032204)
# 2021-06-10 20:00:18.144 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.17214095393098 - for walll (startPoint: -36.30013498150997/41.85274102032204 | endPoint: -71.06513398150996/41.83774102032204)
# 2021-06-10 20:00:18.145 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 97.97 %
# 2021-06-10 20:00:18.167 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 127.19686227319096 - for walll (startPoint: -31.02513498150996/41.85274102032204 | endPoint: -31.02513498150996/40.58774102032204)
# 2021-06-10 20:00:18.177 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686234565754 - for walll (startPoint: -31.02513498150996/40.58774102032204 | endPoint: -19.42513498150997/40.5877410056506)
# 2021-06-10 20:00:18.191 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 307.19686227319096 - for walll (startPoint: -19.42513498150997/40.5877410056506 | endPoint: -19.42513498150997/41.85274102032204)
# 2021-06-10 20:00:18.203 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: -19.42513498150997/41.85274102032204 | endPoint: -31.02513498150996/41.85274102032204)
# 2021-06-10 20:00:18.218 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 127.19686227319096 - for walll (startPoint: -31.02513498150996/41.85274102032204 | endPoint: -31.02513498150996/40.58774102032204)
# 2021-06-10 20:00:18.235 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686234565754 - for walll (startPoint: -31.02513498150996/40.58774102032204 | endPoint: -19.42513498150997/40.5877410056506)
# 2021-06-10 20:00:18.247 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 307.19686227319096 - for walll (startPoint: -19.42513498150997/40.5877410056506 | endPoint: -19.42513498150997/41.85274102032204)
# 2021-06-10 20:00:18.265 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 217.19686227319093 - for walll (startPoint: -19.42513498150997/41.85274102032204 | endPoint: -31.02513498150996/41.85274102032204)
# 2021-06-10 20:00:18.272 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 98.37 %
# 2021-06-10 20:00:18.302 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 127.19686227319096 - for walll (startPoint: -31.05013498150997/-14.44225897967796 | endPoint: -31.05013498150997/-15.65725797967795)
# 2021-06-10 20:00:18.313 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 37.080762720365335 - for walll (startPoint: -31.05013498150997/-15.65725797967795 | endPoint: 18.29986400067327/-15.55725897967796)
# 2021-06-10 20:00:18.329 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 307.19686227319096 - for walll (startPoint: 18.29986400067327/-15.55725897967796 | endPoint: 18.29986400067327/-14.4122151130123)
# 2021-06-10 20:00:18.341 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 37.19681134360922 - for walll (startPoint: 18.29986400067327/-14.4122151130123 | endPoint: -31.05013498150997/-14.41225897967795)
# 2021-06-10 20:00:18.356 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 127.19686227319096 - for walll (startPoint: -31.05013498150997/-14.41225897967795 | endPoint: -31.05013498150997/-14.44225897967796)
# 2021-06-10 20:00:18.368 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 127.19686227319096 - for walll (startPoint: -31.05013498150997/-14.44225897967796 | endPoint: -31.05013498150997/-15.65725797967795)
# 2021-06-10 20:00:18.384 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 37.080762720365335 - for walll (startPoint: -31.05013498150997/-15.65725797967795 | endPoint: 18.29986400067327/-15.55725897967796)
# 2021-06-10 20:00:18.396 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 307.19686227319096 - for walll (startPoint: 18.29986400067327/-15.55725897967796 | endPoint: 18.29986400067327/-14.4122151130123)
# 2021-06-10 20:00:18.410 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 37.19681134360922 - for walll (startPoint: 18.29986400067327/-14.4122151130123 | endPoint: -31.05013498150997/-14.41225897967795)
# 2021-06-10 20:00:18.425 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 127.19686227319096 - for walll (startPoint: -31.05013498150997/-14.41225897967795 | endPoint: -31.05013498150997/-14.44225897967796)
# 2021-06-10 20:00:18.426 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 98.78 %
# 2021-06-10 20:00:18.448 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 13.697465676764173 - for walll (startPoint: -159.4182362553027/-41.23777205696307 | endPoint: -157.4540834808031/-40.38375872020981)
# 2021-06-10 20:00:18.474 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 13.696854427596962 - for walll (startPoint: -156.7064473463652/-42.10325147080471 | endPoint: -158.6705734563077/-42.95727812919058)
# 2021-06-10 20:00:18.488 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 13.697465676764173 - for walll (startPoint: -159.4182362553027/-41.23777205696307 | endPoint: -157.4540834808031/-40.38375872020981)
# 2021-06-10 20:00:18.512 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 13.696854427596962 - for walll (startPoint: -156.7064473463652/-42.10325147080471 | endPoint: -158.6705734563077/-42.95727812919058)
# 2021-06-10 20:00:18.513 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 99.19 %
# 2021-06-10 20:00:18.540 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 114.45685343409009 - for walll (startPoint: -135.27806198151/-33.83185597967794 | endPoint: -134.98205798151/-35.14106597967792)
# 2021-06-10 20:00:18.554 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 17.74163674952908 - for walll (startPoint: -134.98205798151/-35.14106597967792 | endPoint: -108.9747237537936/-25.9542519256328)
# 2021-06-10 20:00:18.581 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 21.625000299650683 - for walll (startPoint: -108.9747237537936/-25.95425192563283 | endPoint: -102.3292204580764/-24.10231161568018)
# 2021-06-10 20:00:18.595 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 45.54618312645857 - for walll (startPoint: -102.3292204580764/-24.10231161568018 | endPoint: -104.25569198151/-23.81957597967792)
# 2021-06-10 20:00:18.625 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 45.546183126456924 - for walll (startPoint: -104.25569198151/-23.81957597967794 | endPoint: -102.3292204580764/-24.10231161568018)
# 2021-06-10 20:00:18.641 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 23.955018429722358 - for walll (startPoint: -102.3292204580764/-24.10231161568018 | endPoint: -88.89985406444201/-20.94213320676773)
# 2021-06-10 20:00:18.653 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 295.4623346621095 - for walll (startPoint: -88.89985406444201/-20.94213320676773 | endPoint: -89.16022047904691/-19.6886757400157)
# 2021-06-10 20:00:18.669 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 24.755142899969034 - for walll (startPoint: -89.16022047904691/-19.6886757400157 | endPoint: -95.77150582989962/-21.14730855800201)
# 2021-06-10 20:00:18.682 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 7.068091651239254 - for walll (startPoint: -95.77150582989962/-21.14730855800201 | endPoint: -96.76588095574299/-21.72439495391097)
# 2021-06-10 20:00:18.712 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 7.068091651239156 - for walll (startPoint: -96.76588095574299/-21.72439495391098 | endPoint: -95.77150582989962/-21.14730855800201)
# 2021-06-10 20:00:18.725 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 20.94904889695178 - for walll (startPoint: -95.77150582989962/-21.14730855800201 | endPoint: -121.7595521807859/-28.72105724573978)
# 2021-06-10 20:00:18.743 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 28.186601105103133 - for walll (startPoint: -121.7595521807859/-28.72105724573978 | endPoint: -119.62131998151/-28.38200197967794)
# 2021-06-10 20:00:18.775 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 28.186601105104 - for walll (startPoint: -119.62131998151/-28.38200197967797 | endPoint: -121.7595521807859/-28.72105724573975)
# 2021-06-10 20:00:18.786 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 16.38173609333075 - for walll (startPoint: -121.7595521807859/-28.72105724573975 | endPoint: -134.4152301818507/-33.53232195611889)
# 2021-06-10 20:00:18.801 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 69.40691030179063 - for walll (startPoint: -134.4152301818507/-33.53232195611889 | endPoint: -134.163347007277/-33.69100295391097)
# 2021-06-10 20:00:18.822 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 69.40691030179129 - for walll (startPoint: -134.163347007277/-33.69100295391098 | endPoint: -134.4152301818507/-33.53232195611889)
# 2021-06-10 20:00:18.834 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 104.91966266530605 - for walll (startPoint: -134.4152301818507/-33.53232195611889 | endPoint: -134.4341625244085/-33.48610776027778)
# 2021-06-10 20:00:18.845 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 14.919662665425822 - for walll (startPoint: -134.4341625244085/-33.48610776027778 | endPoint: -134.5453698748267/-33.53166552915662)
# 2021-06-10 20:00:18.858 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 14.917514923056412 - for walll (startPoint: -134.5453698748267/-33.53166552915662 | endPoint: -135.27806198151/-33.83185597967794)
# 2021-06-10 20:00:18.873 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 114.45685343409009 - for walll (startPoint: -135.27806198151/-33.83185597967794 | endPoint: -134.98205798151/-35.14106597967792)
# 2021-06-10 20:00:18.890 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 17.74163674952908 - for walll (startPoint: -134.98205798151/-35.14106597967792 | endPoint: -108.9747237537936/-25.9542519256328)
# 2021-06-10 20:00:18.913 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 21.625000299650683 - for walll (startPoint: -108.9747237537936/-25.95425192563283 | endPoint: -102.3292204580764/-24.10231161568018)
# 2021-06-10 20:00:18.930 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 45.54618312645857 - for walll (startPoint: -102.3292204580764/-24.10231161568018 | endPoint: -104.25569198151/-23.81957597967792)
# 2021-06-10 20:00:18.967 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 45.546183126456924 - for walll (startPoint: -104.25569198151/-23.81957597967794 | endPoint: -102.3292204580764/-24.10231161568018)
# 2021-06-10 20:00:18.981 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 23.955018429722358 - for walll (startPoint: -102.3292204580764/-24.10231161568018 | endPoint: -88.89985406444201/-20.94213320676773)
# 2021-06-10 20:00:18.994 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 295.4623346621095 - for walll (startPoint: -88.89985406444201/-20.94213320676773 | endPoint: -89.16022047904691/-19.6886757400157)
# 2021-06-10 20:00:19.007 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 24.755142899969034 - for walll (startPoint: -89.16022047904691/-19.6886757400157 | endPoint: -95.77150582989962/-21.14730855800201)
# 2021-06-10 20:00:19.023 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 7.068091651239254 - for walll (startPoint: -95.77150582989962/-21.14730855800201 | endPoint: -96.76588095574299/-21.72439495391097)
# 2021-06-10 20:00:19.044 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 7.068091651239156 - for walll (startPoint: -96.76588095574299/-21.72439495391098 | endPoint: -95.77150582989962/-21.14730855800201)
# 2021-06-10 20:00:19.061 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 20.94904889695178 - for walll (startPoint: -95.77150582989962/-21.14730855800201 | endPoint: -121.7595521807859/-28.72105724573978)
# 2021-06-10 20:00:19.074 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 28.186601105103133 - for walll (startPoint: -121.7595521807859/-28.72105724573978 | endPoint: -119.62131998151/-28.38200197967794)
# 2021-06-10 20:00:19.097 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 28.186601105104 - for walll (startPoint: -119.62131998151/-28.38200197967797 | endPoint: -121.7595521807859/-28.72105724573975)
# 2021-06-10 20:00:19.114 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 16.38173609333075 - for walll (startPoint: -121.7595521807859/-28.72105724573975 | endPoint: -134.4152301818507/-33.53232195611889)
# 2021-06-10 20:00:19.128 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 69.40691030179063 - for walll (startPoint: -134.4152301818507/-33.53232195611889 | endPoint: -134.163347007277/-33.69100295391097)
# 2021-06-10 20:00:19.150 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 69.40691030179129 - for walll (startPoint: -134.163347007277/-33.69100295391098 | endPoint: -134.4152301818507/-33.53232195611889)
# 2021-06-10 20:00:19.164 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 104.91966266530605 - for walll (startPoint: -134.4152301818507/-33.53232195611889 | endPoint: -134.4341625244085/-33.48610776027778)
# 2021-06-10 20:00:19.179 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 14.919662665425822 - for walll (startPoint: -134.4341625244085/-33.48610776027778 | endPoint: -134.5453698748267/-33.53166552915662)
# 2021-06-10 20:00:19.192 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 14.917514923056412 - for walll (startPoint: -134.5453698748267/-33.53166552915662 | endPoint: -135.27806198151/-33.83185597967794)
# 2021-06-10 20:00:19.192 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 99.59 %
# 2021-06-10 20:00:19.222 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 118.41227924217323 - for walll (startPoint: -76.36570553420789/-18.0639293565069 | endPoint: -76.27763841223957/-18.6338226013447)
# 2021-06-10 20:00:19.265 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 32.93870529129763 - for walll (startPoint: -76.27763841223957/-18.6338226013447 | endPoint: -36.30013498150997/-15.65725797967796)
# 2021-06-10 20:00:19.283 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 307.19686227319096 - for walll (startPoint: -36.30013498150997/-15.65725797967796 | endPoint: -36.30013498150997/-15.03475847967795)
# 2021-06-10 20:00:19.294 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 46.526375349210866 - for walll (startPoint: -36.30013498150997/-15.03475847967795 | endPoint: -37.35013498150998/-14.86225897967796)
# 2021-06-10 20:00:19.318 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 226.52637534921044 - for walll (startPoint: -37.35013498150998/-14.86225897967797 | endPoint: -36.30013498150997/-15.03475847967795)
# 2021-06-10 20:00:19.331 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 307.19686227319096 - for walll (startPoint: -36.30013498150997/-15.03475847967795 | endPoint: -36.30013498150997/-14.41225897967795)
# 2021-06-10 20:00:19.347 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 35.53776273030096 - for walll (startPoint: -36.30013498150997/-14.41225897967795 | endPoint: -53.49794798150994/-14.91039097967794)
# 2021-06-10 20:00:19.390 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 31.016804581836233 - for walll (startPoint: -53.49794798150997/-14.91039097967794 | endPoint: -76.45874087311681/-17.3966455866688)
# 2021-06-10 20:00:19.403 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 118.41897537257326 - for walll (startPoint: -76.45874087311681/-17.3966455866688 | endPoint: -76.42400298150999/-17.62161297967795)
# 2021-06-10 20:00:19.412 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 119.68853620066128 - for walll (startPoint: -76.42400298150999/-17.62161297967795 | endPoint: -76.36570553420789/-18.0639293565069)
# 2021-06-10 20:00:19.429 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 118.41227924217323 - for walll (startPoint: -76.36570553420789/-18.0639293565069 | endPoint: -76.27763841223957/-18.6338226013447)
# 2021-06-10 20:00:19.441 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 32.93870529129763 - for walll (startPoint: -76.27763841223957/-18.6338226013447 | endPoint: -36.30013498150997/-15.65725797967796)
# 2021-06-10 20:00:19.453 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 307.19686227319096 - for walll (startPoint: -36.30013498150997/-15.65725797967796 | endPoint: -36.30013498150997/-15.03475847967795)
# 2021-06-10 20:00:19.467 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 46.526375349210866 - for walll (startPoint: -36.30013498150997/-15.03475847967795 | endPoint: -37.35013498150998/-14.86225897967796)
# 2021-06-10 20:00:19.490 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 226.52637534921044 - for walll (startPoint: -37.35013498150998/-14.86225897967797 | endPoint: -36.30013498150997/-15.03475847967795)
# 2021-06-10 20:00:19.502 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 307.19686227319096 - for walll (startPoint: -36.30013498150997/-15.03475847967795 | endPoint: -36.30013498150997/-14.41225897967795)
# 2021-06-10 20:00:19.514 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 35.53776273030096 - for walll (startPoint: -36.30013498150997/-14.41225897967795 | endPoint: -53.49794798150994/-14.91039097967794)
# 2021-06-10 20:00:19.558 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 31.016804581836233 - for walll (startPoint: -53.49794798150997/-14.91039097967794 | endPoint: -76.45874087311681/-17.3966455866688)
# 2021-06-10 20:00:19.576 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 118.41897537257326 - for walll (startPoint: -76.45874087311681/-17.3966455866688 | endPoint: -76.42400298150999/-17.62161297967795)
# 2021-06-10 20:00:19.591 | DEBUG    | app.main.services.orientation_extraction:calculate_orientation:160 - calculated full angle: 119.68853620066128 - for walll (startPoint: -76.42400298150999/-17.62161297967795 | endPoint: -76.36570553420789/-18.0639293565069)
# 2021-06-10 20:00:19.593 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:136 - Progress: 100.0 %
# 2021-06-10 20:00:19.645 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:142 - ####### outer walls & neighbours finished #######

# %%
'''
This method gets the polylines from the layer "leichtwand" and "tragwand", creates architecture walls and matches them to an simple walls.
'''
def matching_simple_walls_with_polygons(simple_walls: list, simple_polygons: list, architecture_polylines: list, layer: str):
    
    #Hilfslisten und variablen
    linestrings_architecture = []
    architecture_wall_list = []
    line_list_total = []
    amount_matches = 0
    counter = 0

    if(type(architecture_polylines[0]) is ezdxf.entities.lwpolyline.LWPolyline):
        print("Polylines werden gematched!")
        #loop durch alle architecture polylines
        for polyline in architecture_polylines:
            # uuid für die wand erzeugen
            uuid_wall = uuid.uuid1()
            # aus jeder architecture_polyline wird eine liste aus linestrings generiert
            linestrings = create_linestring_from_polyline(polyline)
            # jede der linestrings werden in ein object line mit der uuid und einem linestring der Wall zugeorndet
            lines = []
            for x in linestrings:
                points = x.coords
                line = Line(uuid_wall, x, points[0], points[1])
                lines.append(line)
                line_list_total.append(line)
                linestrings_architecture.append(x)
            # wanddicke ermitteln
            wall_thickness = calculate_wallthickness(polyline)
            # erzeugen einer Archtiecture_wall
            architecture_Wall = Architectur_Wall(uuid_wall, polyline, wall_thickness, layer, lines, 0)
            # architecture wall in die liste der architecture walls einfügen.
            architecture_wall_list.append(architecture_Wall)
        print("architecture_Walls created!")
        # loop durch alle simple_polygons:
        #print(len(simple_polygons))
        for simple_polygon in simple_polygons:
            walls = simple_polygon.walls
            # loop durch alle Wände des simple polygons:
            for simple_wall in walls:
                # wall in linestring umwandeln
                simple_line = create_linestring_from_wall(simple_wall)
                #schauen ob linestring von wall eine line im line array schneidet
                for x in line_list_total:
                    boolhandler = simple_line.intersects(x.line_string)
                    if(boolhandler):
                        amount_matches += 1
                        # architekturplan attribute der simple wall zuordnen und architecture wall bekommt hier simplewall id
                        wall_thickness_calc, architecture_wall_object = get_wall_thickness(x, architecture_wall_list)
                        if(simple_wall.wall_thickness == None):
                            simple_wall.wall_thickness = wall_thickness_calc
                        simple_wall.id = uuid.uuid1()
                        architecture_wall_object.simple_wall_id = simple_wall.id
                        simple_wall.wall_type = layer
                

    for simple_polygon in simple_polygons:
        walls = simple_polygon.walls
        for simple_wall in walls:
            if(simple_wall.wall_thickness != None):
                #ungleich None wanddicke zugeordnet:
                counter += 1

    print('Von ' + str(amount_matches) + ' Matches konnten ' + str(counter) + ' Wanddicken zugeordnet werden.')
    print('FERTIG__________')           
    return simple_polygons, architecture_wall_list


''' Mock-Method for preparation of integration
'''
def coordinate_matching(simple_walls: list, simple_polygons: list, architecture_polyline_for_scale: list, simple_polyline_for_scale: list, architecture_polylines: list , layer:str):
    matched_simplepolygons = []
    layer
    #simple_walls: list, simple_polygons: list, architecture_polylines: list, layer: str
    # Überprüfen des Matchings auf scale Factor
    boolhandler = check_scaling(architecture_polyline_for_scale, simple_polyline_for_scale)
    #print(boolhandler)
    if(boolhandler):
        #ab hier muss das matching koordiniert werden.
        #Layer leichtwand
        if(layer == 1 ):
            layer_name = 'Leichtwand'
            architecture_polylines1, layer1 = get_polylines_by_layer('A_02_LEICHTWAND', 'LWPolyline')
            simplepolygons, architecture_walls = matching_simple_walls_with_polygons(simple_walls, simple_polygons, architecture_polylines, layer_name)
        #layer Tragwand
        if(layer == 2 ):
            layer_name2 = 'Tragwand'
            architecture_polylines2, layer2 = get_polylines_by_layer('A_01_TRAGWAND', 'LWPolyline')
            simplepolygons, architecture_walls = matching_simple_walls_with_polygons(simple_walls, simple_polygons, architecture_polylines, layer_name2)
    return simplepolygons, architecture_walls

# %%
# For Testing

res1, res2 = coordinate_matching(simple_walls, simple_polygons, architecture_polylines_for_scale, simple_polylines_for_scale, architecture_polylines1, 1)

res3, res4 = coordinate_matching(simple_walls, simple_polygons, architecture_polylines_for_scale, simple_polylines_for_scale, architecture_polylines2, 2)
#print(res1[1])
#print(res2[0])
# Out:
# Polylines werden gematched!
# architecture_Walls created!
# Von 368 Matches konnten 269 Wanddicken zugeordnet werden.
# FERTIG__________
# Polylines werden gematched!
# architecture_Walls created!
# Von 878 Matches konnten 904 Wanddicken zugeordnet werden.
# FERTIG__________
