# %% [markdown]
# ## Importsetup

# %%
###########################################################################
from app.main.extraction.dxf_extraction_coordinator import DxfExtractionCoordinator
from app.main.models.wall import Wall 
from app.main.models.architecture_wall import Architecture_Wall
from app.main.models.point import Point 
from app.main.models.pillar import Pillar
from app.main.services.walls_extraction import WallsExtraction
from app.main.services.dxf_extraction_simple import DxfExtractionSimple
from app.main.dtos.request.extraction_request_file import ExtractionRequestFile
from app.main.models.line import Line 
###########################################################################
from shapely.geometry.polygon import LinearRing
from shapely.geometry.polygon import Polygon as shapePolygon
from shapely.geometry import Point as shapePoint
from shapely.geometry import LineString
import math
import numpy as np
import itertools as it
from scipy.spatial.distance import cdist
import ezdxf
import uuid

import matplotlib.pyplot as plt
import operator

###########################################################################
file_path_simple = '../../media/Einfache_Plaene_Compass/'
file_path_architecture = '../../media/Architektenplaene/'
###########################################################################
file_name_simple = 'R-Bau_D_EG.dxf'
file_name_architecutre = 'R-Bau_A_EG.dxf'
###########################################################################
simple_dxf = ezdxf.readfile(file_path_simple+file_name_simple)
architecture_dxf = ezdxf.readfile(file_path_architecture+file_name_architecutre)
simple_model = simple_dxf.modelspace()
arichtecture_model = architecture_dxf.modelspace()

# %%
'''This cell gets all the circle entities from the architecture plan.'''
pillars = arichtecture_model.query("CIRCLE[layer=='A_01_STUETZE']")

# %% [markdown]
# ### In the block below there will be created a dxf-File for analysis purposes.

# %%
doc = ezdxf.new('R2000')
msp = doc.modelspace()
#Read pillar circles from architecture wall
architecture_polylines = []
architecture_lines = []
saeulen_polylines = arichtecture_model.query("LWPolyline[layer=='A_01_STUETZE']")#.first.get_points('xy')
saeulen_lines = arichtecture_model.query("LINE[layer=='A_01_STUETZE']")

pillars = arichtecture_model.query("CIRCLE[layer=='A_01_STUETZE']")
doc.layers.new(name='SAULEN_LINES', dxfattribs={'linetype': 'DASHED', 'color': 1})
doc.layers.new(name='SAULEN_POLYLINES', dxfattribs={'linetype': 'DASHED', 'color': 2})
doc.layers.new(name='SAULEN_CIRCLES', dxfattribs={'linetype': 'DASHED', 'color': 3})

print(len(saeulen_lines))
print(len(saeulen_polylines))
for polyline in saeulen_polylines:
    architecture_polylines.append(polyline)

for line in saeulen_lines:
    architecture_lines.append(line)


for x in architecture_polylines:
    msp.add_lwpolyline(x, dxfattribs={'layer': 'SAULEN_POLYLINES'})

#add lines to drawing
coordinates = []
for e in architecture_lines:
    if e.dxftype() == 'LINE':
        tupel = (e.dxf.start, e.dxf.end)
        coordinates.append(tupel)

for x in coordinates:
    msp.add_line(x[0], x[1], dxfattribs={'layer': 'SAULEN_LINES'})

for x in pillars:
    msp.add_circle(x.dxf.center, x.dxf.radius, dxfattribs={'layer': 'SAULEN_CIRCLES'})

doc.saveas("pillars.dxf")
# Out:
# 1
# 19

# %%
''' This method creates an architecture plan pillar with a center coordinate point an a radius.'''
def create_architecture_pillar(center: tuple, radius: float):
    center_point = Point(center[0], center[1])
    pillar_id = str(uuid.uuid4())
    return Pillar(center_point=center_point, radius=radius, pillar_id=pillar_id)

# %% [markdown]
# ### The following block transform all pillars intow achritecutre pillars.

# %%
#transform pillars to model
architecture_pillars = []
for pillar in pillars:
    architecture_pillar = create_architecture_pillar(pillar.dxf.center, pillar.dxf.radius)
    architecture_pillars.append(architecture_pillar)

# %% [markdown]
# ### The following block extracts all polygons from the given simple plan.

# %%
#read simple plan
dxf_file = ezdxf.readfile(file_path_simple + file_name_simple)
dxf_extraction_simple = DxfExtractionSimple()
simple_polygons, polygons_with_virtual_entities, extracted_functionalities, counter_polygon_closed = dxf_extraction_simple.get_all_polygons(dxf_file ,file_path_simple + file_name_simple)
# Out:
# 2021-06-18 10:42:30.423 | SUCCESS  | app.main.services.orientation_extraction:get_north_orientation:116 - Compass extraction successful, return coordinate system
# 2021-06-18 10:42:30.423 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:97 - Orientation will be calculated with compass.
# 2021-06-18 10:42:30.424 | SUCCESS  | app.main.services.extraction_helper:get_modelspace:191 - sucessfully get_modelspace() from dxf_file: <ezdxf.document.Drawing object at 0x000001AD826C6190>
# 2021-06-18 10:42:30.425 | DEBUG    | app.main.services.extraction_helper:get_outline_polygon:200 - get_outline_polygon for modelspace: <ezdxf.layouts.layout.Modelspace object at 0x000001AD8507B1F0>
# 2021-06-18 10:42:30.475 | DEBUG    | app.main.services.dxf_extraction_simple:get_all_polygons:145 - got all room_polylines on layer: RAUMPOLYGON
# 2021-06-18 10:42:30.824 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:192 - Extracting neighbours...
# Neighbours - Progress: 100%|██████████| 246/246 [00:02<00:00, 104.17it/s]
# 2021-06-18 10:42:33.189 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:200 - Neighbours extracted
# 2021-06-18 10:42:33.190 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:205 - Extracting outer walls...
# Outer Walls - Progress: 100%|██████████| 246/246 [00:29<00:00,  8.26it/s]
# 2021-06-18 10:43:02.992 | INFO     | app.main.services.dxf_extraction_simple:get_all_polygons:221 - Outer walls extracted

# %%
''' This method calculates the lenght in between two points'''
def get_length_between_points(point_1: Point, point_2: Point) -> float:
    line_string = LineString([(point_1.x_coordinate, point_1.y_coordinate), (point_2.x_coordinate, point_2.y_coordinate)])
    return line_string.length

# %%
''' This method maps all pillars to simple pillars extracted from the simple plan'''
def map_pillars_to_simple_pillars(simple_polygons: list, architecture_pillars: list[Pillar]):
    #loop trough simple polygons
    min_pillar_distances = []
    threshold = 0.00104
    for polygon in simple_polygons:
        #if there are pillar in the polygon
        if polygon.pillars:
            #loop through all simple pillars
            for simple_pillar in polygon.pillars:
                pillar_distances = []
                potential_pillar = None
                potential_pillar_distance = 0
                # for each architecture pillar there will be calculated the distance to the simple pillar
                for architecture_pillar in architecture_pillars:
                    # calculate the distance between simple pillar and architecutre pillar
                    pillar_distance = get_length_between_points(simple_pillar.start_point, architecture_pillar.center_point)
                    if not potential_pillar:
                        # if potentail pillar is not none
                        # overwrite with value of architecture pillar and pillar distance
                        potential_pillar = architecture_pillar
                        potential_pillar_distance = pillar_distance
                    elif pillar_distance < potential_pillar_distance:
                        # else check if the distance is smaller than the potential distance
                        potential_pillar = architecture_pillar
                        potential_pillar_distance = pillar_distance
                
                # Check if potential pillar distance is smaller than the range of the radius plus the threshold value
                if potential_pillar_distance < potential_pillar.radius + threshold:
                    print("Pillar with id {} matched!".format(potential_pillar.pillar_id))
                    simple_pillar.pillar_id = potential_pillar.pillar_id
                    simple_pillar.center_point = potential_pillar.center_point
                    simple_pillar.radius = potential_pillar.radius
                else:
                    print("false")
                    print("Distanz: {}, radius: {}.".format(str(potential_pillar_distance), str(potential_pillar.radius)))
                    print("Differenz: {}".format(str(potential_pillar_distance - potential_pillar.radius)))
    
    # @nico bitte was?
    pillars_flat = []
    for polygon in simple_polygons:
        if polygon.pillars:
            for simple_pillar in polygon.pillars:
                pillars_flat.append(simple_pillar)
                print(simple_pillar)
    
    pillar_ids = []
    for pillar in pillars_flat:
        pillar_ids.append(pillar.pillar_id)
    print("Amount of pillars: {}".format(str(len(pillar_ids))))
    has_duplicate_items = any(pillar_ids.count(x) > 1 for x in pillar_ids)
    print("Duplicate pilllar matches? {}".format(str(has_duplicate_items)))

# %%
# Testing the method
map_pillars_to_simple_pillars(simple_polygons, architecture_pillars)
# Out:
# Pillar with id d114a0d4-bc17-4c64-ba91-c014c8817631 matched!
# Pillar with id 8f65d8bc-4847-4adb-9e3d-e026a5e8d18f matched!
# Pillar with id bdddd078-397b-46d9-adc0-71a4a333f3b1 matched!
# Pillar with id c561f4bc-a0de-4f15-8f73-25114bb23acc matched!
# Pillar with id 616bc19c-0336-480b-bcb3-b9297bf4a8cf matched!
# Pillar with id 1189436c-1eb0-421c-8631-33200c6750f6 matched!
# Pillar with id 4b160b21-7eb0-4865-a7be-ab2aaa44c64c matched!
# Pillar with id 4e229b0b-be50-4f5b-b743-992c554c54f1 matched!
# Pillar with id b41fbcf6-ef26-43fe-aa29-9e993e489967 matched!
# Pillar with id c1ffb4a9-1b02-4ba5-b941-26ac4d69e98e matched!
# Pillar with id 511f5ea3-95fe-403c-adb3-fb3062eb850f matched!
# Pillar with id 214da17f-cfa9-4083-ad0f-3f47c9513a27 matched!
# Pillar with id 1f761177-4812-4173-88a9-807d942e26aa matched!
# Pillar with id def2bde3-9950-42f2-972d-260135cb9309 matched!
# Pillar with id 77897350-6a6c-4bc3-b471-f56b2b6bda82 matched!
# Pillar with id 410f0d32-e61f-4e52-b363-2a795cc169e8 matched!
# Pillar with id c5648b7a-5f95-459c-8730-57a195e1e836 matched!
# Pillar with id 02ca0ed1-d570-495d-964f-77ba3b8ecce2 matched!
# Pillar with id 12da9c35-42e3-4529-ac79-d96024c21a4d matched!
# Pillar with id 0e191f4e-ef07-4905-8fa1-d3fa3e6a1a69 matched!
# Pillar with id f38ca1e9-76b6-4f0f-880b-483abdc77b19 matched!
# Pillar with id 8a788869-332e-4cc4-821c-eecdfe36936c matched!
# Pillar with id 6fa2cb69-dad2-4ad1-900c-05bbbd5f5716 matched!
# Pillar with id c81c4620-d53c-4395-8c23-ddaa3b47e46e matched!
# Pillar with id 89336079-bb6f-40d1-a8ea-cc6e4518ab36 matched!
# Pillar with id dbe3c00b-7bc4-4e44-812b-f50135ce5952 matched!
# Pillar with id e34c3dc0-8f8c-416b-aee7-820caa5d1448 matched!
# Pillar with id 426fbfff-90fd-4d8a-b6b6-d9e0aff691bf matched!
# Pillar with id be4f4c4d-d699-4748-954b-a73e49eef936 matched!
# Pillar with id 634617e5-b36e-4498-8073-beabd535b6f0 matched!
# Pillar with id 0e2302d7-0fc1-48b1-aa1c-9164f95a13a2 matched!
# Pillar with id ab0edacb-d34e-4ca9-85a3-f067f9cf7d76 matched!
# Pillar with id 39ee4aa1-ec2d-467c-b346-281d6fe7b4ed matched!
# Pillar with id 72f46e39-e01c-442d-bd2d-9cfdb7b1e86c matched!
# Pillar with id 11e9468d-5bb0-45a3-88b7-bf4b7a8c3270 matched!
# Pillar with id 3e52e8b2-a640-4a25-a28f-8e1ac7013306 matched!
# Pillar with id a3c19d67-c4c5-4a2c-a215-985cf7b06dba matched!
# Pillar with id 68fec8ef-1e71-4ffc-be65-840bba9116c6 matched!
# Pillar with id cda93eaf-0153-4718-b7b9-f4792d17b553 matched!
# Pillar with id 54938b7f-2c9a-4f99-8b6d-180336397775 matched!
# Pillar with id cd4265fe-0e22-47ea-a197-90f80e6e4358 matched!
# Pillar with id 0b78b848-1504-4703-9d62-424c8b4987e2 matched!
# Pillar with id 93e08f10-5b88-4567-ad45-f9a74df62766 matched!
# Pillar with id a64e4721-7e8d-49ef-8b1c-091f24e8ed12 matched!
# Pillar with id aefbe418-7458-42cf-a72a-9c4b8a7a7a68 matched!
# Pillar with id c8e2eb8a-68d2-4510-be26-46d7e4f0e869 matched!
# Pillar with id 670d5fb0-3cc2-4cc4-b1a8-7a031433267f matched!
# Pillar with id 5dcb9094-6227-470b-a1ae-2e212517d8c4 matched!
# Pillar with id 1de46332-7325-41d8-9b02-c42ad75863d3 matched!
# Pillar with id d3fe4ecf-1176-4ae9-931e-fd64719203cb matched!
# Pillar with id 8606f0f3-aef3-4e65-9f08-37ccbd0671af matched!
# Pillar with id 5805b4f2-1daf-4a06-b344-c412be4e4d47 matched!
# Pillar with id 5dfad11c-c1b6-4c57-aae4-7c7097052b72 matched!
# Pillar with id c18470f3-aaa9-4e0d-ba5e-29f6c0a65998 matched!
# Pillar with id e268393c-641b-4d59-988c-d9c8b5cfe47c matched!
# Pillar with id c3747ac4-49be-4e71-904f-8ff6511a7bed matched!
# Pillar with id 41478028-300a-4626-8e4b-096b846b5e46 matched!
# Pillar with id 25381c57-f950-4005-a7d6-763b8f557e4c matched!
# Pillar with id 7781b97d-e8b9-4ada-8ddf-0105a8d131b5 matched!
# Pillar with id 27512736-2522-403a-a2eb-6e6bbacaa3ea matched!
# Pillar with id cb36f29a-e8db-428b-9f75-e40c7ed8bc16 matched!
# Pillar with id ba9839a5-939c-4296-b8ef-919cf68017a4 matched!
# Pillar with id ecd57a10-b8b0-470d-b7bb-fda76f59c459 matched!
# Pillar with id 61961a89-cbe3-401e-8006-d1893ee04cae matched!
# Pillar with id a0e9e19d-1997-4351-9660-2fa90f008760 matched!
# Pillar with id 282772ee-ada7-4efd-a634-fee0fe46db73 matched!
# Pillar(start_point=Point(x_coordinate=-173.6154199777118, y_coordinate=-22.16380538192807, s_width=0.0, e_width=0.0, b_value=-1.73205080739057), end_point=Point(x_coordinate=-173.6154199777118, y_coordinate=-22.16380538192807, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-173.5265718496499, y_coordinate=-22.01183585107773, s_width=None, e_width=None, b_value=None), radius=0.175, pillar_id='d114a0d4-bc17-4c64-ba91-c014c8817631')
# Pillar(start_point=Point(x_coordinate=-165.437464977712, y_coordinate=-14.38545601702271, s_width=0.0, e_width=0.0, b_value=-1.732050807388588), end_point=Point(x_coordinate=-165.437464977712, y_coordinate=-14.38545601702271, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-165.3361168496498, y_coordinate=-14.21183585107775, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='8f65d8bc-4847-4adb-9e3d-e026a5e8d18f')
# Pillar(start_point=Point(x_coordinate=-172.9322009777118, y_coordinate=-14.36380538192807, s_width=0.0, e_width=0.0, b_value=-1.73205080739056), end_point=Point(x_coordinate=-172.9322009777118, y_coordinate=-14.36380538192807, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-172.8433528496499, y_coordinate=-14.21183585107775, s_width=None, e_width=None, b_value=None), radius=0.175, pillar_id='bdddd078-397b-46d9-adc0-71a4a333f3b1')
# Pillar(start_point=Point(x_coordinate=-164.555054977712, y_coordinate=-6.585456017022812, s_width=0.0, e_width=0.0, b_value=-3.732050806897012), end_point=Point(x_coordinate=-164.555054977712, y_coordinate=-6.585456017022812, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-164.6537068496498, y_coordinate=-6.41183585107774, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='c561f4bc-a0de-4f15-8f73-25114bb23acc')
# Pillar(start_point=Point(x_coordinate=-160.9761669777119, y_coordinate=-6.585456017022791, s_width=0.0, e_width=0.0, b_value=-3.732050806897844), end_point=Point(x_coordinate=-160.9761669777119, y_coordinate=-6.585456017022791, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-161.0748188496499, y_coordinate=-6.41183585107774, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='616bc19c-0336-480b-bcb3-b9297bf4a8cf')
# Pillar(start_point=Point(x_coordinate=-170.2009267637938, y_coordinate=17.13774902008333, s_width=0.0, e_width=0.0, b_value=-3.542888052349912), end_point=Point(x_coordinate=-170.2009267637938, y_coordinate=17.13774902008333, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-170.1104778496499, y_coordinate=16.98816414892229, s_width=None, e_width=None, b_value=None), radius=0.175, pillar_id='1189436c-1eb0-421c-8631-33200c6750f6')
# Pillar(start_point=Point(x_coordinate=-162.27512898151, y_coordinate=17.1609541010789, s_width=0.0, e_width=0.0, b_value=-1.732050807389507), end_point=Point(x_coordinate=-162.27512898151, y_coordinate=17.1609541010789, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-162.3748188496499, y_coordinate=16.98816414892229, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='4b160b21-7eb0-4865-a7be-ab2aaa44c64c')
# Pillar(start_point=Point(x_coordinate=-154.42512898151, y_coordinate=41.23774902032204, s_width=0.0, e_width=0.0, b_value=-2.999999999999774), end_point=Point(x_coordinate=-154.42512898151, y_coordinate=41.23774902032204, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-154.5748188496499, y_coordinate=41.03816414892228, s_width=None, e_width=None, b_value=None), radius=0.25, pillar_id='4e229b0b-be50-4f5b-b743-992c554c54f1')
# Pillar(start_point=Point(x_coordinate=-159.6751289815099, y_coordinate=48.01454393956519, s_width=0.0, e_width=0.0, b_value=-3.732050806899101), end_point=Point(x_coordinate=-159.6751289815099, y_coordinate=48.01454393956519, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-159.7748188496499, y_coordinate=48.18816414892228, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='b41fbcf6-ef26-43fe-aa29-9e993e489967')
# Pillar(start_point=Point(x_coordinate=-154.37512898151, y_coordinate=48.18774902032204, s_width=0.0, e_width=0.0, b_value=-0.9999999999999999), end_point=Point(x_coordinate=-154.37512898151, y_coordinate=48.18774902032204, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-154.5748188496499, y_coordinate=48.18816414892228, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='c1ffb4a9-1b02-4ba5-b941-26ac4d69e98e')
# Pillar(start_point=Point(x_coordinate=-154.6751289815099, y_coordinate=54.86095410107892, s_width=0.0, e_width=0.0, b_value=-3.732050806898507), end_point=Point(x_coordinate=-154.6751289815099, y_coordinate=54.86095410107892, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-154.5748188496499, y_coordinate=54.68816414892228, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='511f5ea3-95fe-403c-adb3-fb3062eb850f')
# Pillar(start_point=Point(x_coordinate=-159.8751289815099, y_coordinate=54.8609541010789, s_width=0.0, e_width=0.0, b_value=-3.732050806899167), end_point=Point(x_coordinate=-159.8751289815099, y_coordinate=54.8609541010789, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-159.7748188496499, y_coordinate=54.68816414892228, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='214da17f-cfa9-4083-ad0f-3f47c9513a27')
# Pillar(start_point=Point(x_coordinate=-162.3751289815099, y_coordinate=40.81274902032206, s_width=0.0, e_width=0.0, b_value=-2.41421356206663), end_point=Point(x_coordinate=-162.3751289815099, y_coordinate=40.81274902032206, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-162.3748188496499, y_coordinate=41.03816414892228, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='1f761177-4812-4173-88a9-807d942e26aa')
# Pillar(start_point=Point(x_coordinate=-139.1751289815099, y_coordinate=44.48248102032206, s_width=0.0, e_width=0.0, b_value=-0.9999999999999999), end_point=Point(x_coordinate=-139.1751289815099, y_coordinate=44.48248102032206, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-138.9748188496499, y_coordinate=44.48289614892226, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='def2bde3-9950-42f2-972d-260135cb9309')
# Pillar(start_point=Point(x_coordinate=-139.22512898151, y_coordinate=41.03774902032205, s_width=0.0, e_width=0.0, b_value=-0.9999999999999999), end_point=Point(x_coordinate=-139.22512898151, y_coordinate=41.03774902032205, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-138.9748188496499, y_coordinate=41.03816414892225, s_width=None, e_width=None, b_value=None), radius=0.25, pillar_id='77897350-6a6c-4bc3-b471-f56b2b6bda82')
# Pillar(start_point=Point(x_coordinate=-131.3519056768066, y_coordinate=40.86097232502541, s_width=0.0, e_width=0.0, b_value=-1.496605762520032), end_point=Point(x_coordinate=-131.3519056768066, y_coordinate=40.86097232502541, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-131.1748188496499, y_coordinate=41.03816414892225, s_width=None, e_width=None, b_value=None), radius=0.25, pillar_id='410f0d32-e61f-4e52-b363-2a795cc169e8')
# Pillar(start_point=Point(x_coordinate=-131.07512898151, y_coordinate=47.70081293956513, s_width=0.0, e_width=0.0, b_value=-3.732050806897907), end_point=Point(x_coordinate=-131.07512898151, y_coordinate=47.70081293956513, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-131.1748188496499, y_coordinate=47.87443314892226, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='c5648b7a-5f95-459c-8730-57a195e1e836')
# Pillar(start_point=Point(x_coordinate=-139.22512898151, y_coordinate=24.78774902032205, s_width=0.0, e_width=0.0, b_value=-0.9999999999999999), end_point=Point(x_coordinate=-139.22512898151, y_coordinate=24.78774902032205, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-138.9748188496499, y_coordinate=24.78816414892225, s_width=None, e_width=None, b_value=None), radius=0.25, pillar_id='02ca0ed1-d570-495d-964f-77ba3b8ecce2')
# Pillar(start_point=Point(x_coordinate=-139.1751289815099, y_coordinate=16.98774902032205, s_width=0.0, e_width=0.0, b_value=-0.9999999999999999), end_point=Point(x_coordinate=-139.1751289815099, y_coordinate=16.98774902032205, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-138.9748188496499, y_coordinate=16.98816414892227, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='12da9c35-42e3-4529-ac79-d96024c21a4d')
# Pillar(start_point=Point(x_coordinate=-139.07512898151, y_coordinate=9.360954101078931, s_width=0.0, e_width=0.0, b_value=-3.732050806898457), end_point=Point(x_coordinate=-139.07512898151, y_coordinate=9.360954101078931, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-138.9748188496499, y_coordinate=9.188164148922255, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='0e191f4e-ef07-4905-8fa1-d3fa3e6a1a69')
# Pillar(start_point=Point(x_coordinate=-123.6849929815099, y_coordinate=7.077432101078957, s_width=0.0, e_width=0.0, b_value=-1.732050807388845), end_point=Point(x_coordinate=-123.6849929815099, y_coordinate=7.077432101078957, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-123.7846828496499, y_coordinate=6.90464214892225, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='f38ca1e9-76b6-4f0f-880b-483abdc77b19')
# Pillar(start_point=Point(x_coordinate=-130.97512898151, y_coordinate=24.78774902032205, s_width=0.0, e_width=0.0, b_value=-0.9999999999999999), end_point=Point(x_coordinate=-130.97512898151, y_coordinate=24.78774902032205, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-131.1748188496499, y_coordinate=24.78816414892225, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='8a788869-332e-4cc4-821c-eecdfe36936c')
# Pillar(start_point=Point(x_coordinate=-113.7955257640388, y_coordinate=55.34392300024749, s_width=0.0, e_width=0.0, b_value=-0.9999999999999999), end_point=Point(x_coordinate=-113.7955257640388, y_coordinate=55.34392300024749, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-113.9952156321787, y_coordinate=55.34433812884768, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='6fa2cb69-dad2-4ad1-900c-05bbbd5f5716')
# Pillar(start_point=Point(x_coordinate=-123.5519056768066, y_coordinate=41.21452571561869, s_width=0.0, e_width=0.0, b_value=-5.027339490946479), end_point=Point(x_coordinate=-123.5519056768066, y_coordinate=41.21452571561869, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-123.3748188496499, y_coordinate=41.03816414892225, s_width=None, e_width=None, b_value=None), radius=0.25, pillar_id='c81c4620-d53c-4395-8c23-ddaa3b47e46e')
# Pillar(start_point=Point(x_coordinate=-92.26644106579651, y_coordinate=32.82047013564363, s_width=0.0, e_width=0.0, b_value=-2.875310952858294), end_point=Point(x_coordinate=-92.26644106579651, y_coordinate=32.82047013564363, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-92.17481884964985, y_coordinate=32.58816414892226, s_width=None, e_width=None, b_value=None), radius=0.25, pillar_id='89336079-bb6f-40d1-a8ea-cc6e4518ab36')
# Pillar(start_point=Point(x_coordinate=-120.47512898151, y_coordinate=24.61454393956516, s_width=0.0, e_width=0.0, b_value=-3.732050806897877), end_point=Point(x_coordinate=-120.47512898151, y_coordinate=24.61454393956516, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-120.5748188496499, y_coordinate=24.78816414892225, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='dbe3c00b-7bc4-4e44-812b-f50135ce5952')
# Pillar(start_point=Point(x_coordinate=-115.47512898151, y_coordinate=27.21454193956518, s_width=0.0, e_width=0.0, b_value=-3.732050806899193), end_point=Point(x_coordinate=-115.47512898151, y_coordinate=27.21454193956518, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-115.5748188496499, y_coordinate=27.38816214892225, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='e34c3dc0-8f8c-416b-aee7-820caa5d1448')
# Pillar(start_point=Point(x_coordinate=-100.1511973596675, y_coordinate=41.17783629600861, s_width=0.0, e_width=0.0, b_value=-17.63664655885315), end_point=Point(x_coordinate=-100.1511973596675, y_coordinate=41.17783629600861, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-99.97481884964992, y_coordinate=41.03816414892225, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='426fbfff-90fd-4d8a-b6b6-d9e0aff691bf')
# Pillar(start_point=Point(x_coordinate=-92.1505956488143, y_coordinate=41.26136962874814, s_width=0.0, e_width=0.0, b_value=-0.8961964536532945), end_point=Point(x_coordinate=-92.20016815937153, y_coordinate=41.26128392733267, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-92.17481884964985, y_coordinate=41.03816414892225, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='be4f4c4d-d699-4748-954b-a73e49eef936')
# Pillar(start_point=Point(x_coordinate=-76.46957041771655, y_coordinate=41.23643958435001, s_width=0.0, e_width=0.0, b_value=-4.204917665412173), end_point=Point(x_coordinate=-76.46957041771655, y_coordinate=41.23643958435001, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-76.57481884964989, y_coordinate=41.03816414892222, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='634617e5-b36e-4498-8073-beabd535b6f0')
# Pillar(start_point=Point(x_coordinate=-84.47210098150997, y_coordinate=41.24077402032204, s_width=0.0, e_width=0.0, b_value=-5.82842801313762), end_point=Point(x_coordinate=-84.47210098150997, y_coordinate=41.24077402032204, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-84.3748188496499, y_coordinate=41.03816414892225, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='0e2302d7-0fc1-48b1-aa1c-9164f95a13a2')
# Pillar(start_point=Point(x_coordinate=-37.57513498150995, y_coordinate=32.83774102032204, s_width=0.0, e_width=0.0, b_value=-2.414213562066522), end_point=Point(x_coordinate=-37.57513498150995, y_coordinate=32.83774102032204, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-37.57481884964989, y_coordinate=32.58816414892226, s_width=None, e_width=None, b_value=None), radius=0.25, pillar_id='ab0edacb-d34e-4ca9-85a3-f067f9cf7d76')
# Pillar(start_point=Point(x_coordinate=24.34486487264495, y_coordinate=-2.405829832428866, s_width=0.0, e_width=0.0, b_value=-1.497072007894928), end_point=Point(x_coordinate=24.34486487264495, y_coordinate=-2.405829832428866, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=24.19518115035015, y_coordinate=-2.405492851077724, s_width=None, e_width=None, b_value=None), radius=0.15, pillar_id='39ee4aa1-ec2d-467c-b346-281d6fe7b4ed')
# Pillar(start_point=Point(x_coordinate=12.99764873775781, y_coordinate=10.57633943488341, s_width=0.0, e_width=0.0, b_value=-3.297411722794304), end_point=Point(x_coordinate=12.99764873775781, y_coordinate=10.57633943488341, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=12.94060215035012, y_coordinate=10.43816414892225, s_width=None, e_width=None, b_value=None), radius=0.15, pillar_id='72f46e39-e01c-442d-bd2d-9cfdb7b1e86c')
# Pillar(start_point=Point(x_coordinate=9.118799018490037, y_coordinate=13.19380702032205, s_width=0.0, e_width=0.0, b_value=-2.412250946047203), end_point=Point(x_coordinate=9.118799018490037, y_coordinate=13.19380702032205, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=9.225181150350124, y_coordinate=13.08816414892226, s_width=None, e_width=None, b_value=None), radius=0.15, pillar_id='11e9468d-5bb0-45a3-88b7-bf4b7a8c3270')
# Pillar(start_point=Point(x_coordinate=-83.3647041003942, y_coordinate=-10.35147537634694, s_width=0.0, e_width=0.0, b_value=-0.5515660589170376), end_point=Point(x_coordinate=-83.3647041003942, y_coordinate=-10.35147537634694, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-83.11714277519826, y_coordinate=-10.38808002230766, s_width=None, e_width=None, b_value=None), radius=0.25001, pillar_id='3e52e8b2-a640-4a25-a28f-8e1ac7013306')
# Pillar(start_point=Point(x_coordinate=-60.90013498150996, y_coordinate=16.42421720975439, s_width=0.0, e_width=0.0, b_value=-3.732050806898146), end_point=Point(x_coordinate=-60.90013498150996, y_coordinate=16.42421720975439, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-60.97481884964986, y_coordinate=16.55454414892222, s_width=None, e_width=None, b_value=None), radius=0.15, pillar_id='a3c19d67-c4c5-4a2c-a215-985cf7b06dba')
# Pillar(start_point=Point(x_coordinate=-45.45013498150992, y_coordinate=16.07566620975441, s_width=0.0, e_width=0.0, b_value=-1.732050807389968), end_point=Point(x_coordinate=-45.45013498150992, y_coordinate=16.07566620975441, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-45.3748188496499, y_coordinate=16.2059931489222, s_width=None, e_width=None, b_value=None), radius=0.15, pillar_id='68fec8ef-1e71-4ffc-be65-840bba9116c6')
# Pillar(start_point=Point(x_coordinate=-37.74924448344193, y_coordinate=9.28615867924302, s_width=0.0, e_width=0.0, b_value=-3.732050806898222), end_point=Point(x_coordinate=-37.74924448344193, y_coordinate=9.28615867924302, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-37.57481884964989, y_coordinate=9.188165148922252, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='cda93eaf-0153-4718-b7b9-f4792d17b553')
# Pillar(start_point=Point(x_coordinate=-29.85013498151, y_coordinate=14.51739820975438, s_width=0.0, e_width=0.0, b_value=-1.732050807388942), end_point=Point(x_coordinate=-29.85013498151, y_coordinate=14.51739820975438, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-29.77481884964988, y_coordinate=14.64772514892226, s_width=None, e_width=None, b_value=None), radius=0.15, pillar_id='54938b7f-2c9a-4f99-8b6d-180336397775')
# Pillar(start_point=Point(x_coordinate=-22.05013498150997, y_coordinate=13.27661420975439, s_width=0.0, e_width=0.0, b_value=-1.732050807389131), end_point=Point(x_coordinate=-22.05013498150997, y_coordinate=13.27661420975439, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-21.97481884964986, y_coordinate=13.40694114892227, s_width=None, e_width=None, b_value=None), radius=0.15, pillar_id='cd4265fe-0e22-47ea-a197-90f80e6e4358')
# Pillar(start_point=Point(x_coordinate=1.252578862995747, y_coordinate=1.286166020322046, s_width=0.0, e_width=0.0, b_value=-0.4142135623730534), end_point=Point(x_coordinate=1.252578862995747, y_coordinate=1.286166020322046, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=1.425181150350113, y_coordinate=1.388164148922272, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='0b78b848-1504-4703-9d62-424c8b4987e2')
# Pillar(start_point=Point(x_coordinate=-6.30013498150997, y_coordinate=21.66764483088971, s_width=0.0, e_width=0.0, b_value=-1.73205080738933), end_point=Point(x_coordinate=-6.30013498150997, y_coordinate=21.66764483088971, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-6.374818849649898, y_coordinate=21.53816414892228, s_width=None, e_width=None, b_value=None), radius=0.15, pillar_id='93e08f10-5b88-4567-ad45-f9a74df62766')
# Pillar(start_point=Point(x_coordinate=-14.10013498150995, y_coordinate=21.6676448308897, s_width=0.0, e_width=0.0, b_value=-1.732050807389167), end_point=Point(x_coordinate=-14.10013498150995, y_coordinate=21.6676448308897, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-14.17481884964991, y_coordinate=21.53816414892228, s_width=None, e_width=None, b_value=None), radius=0.15, pillar_id='a64e4721-7e8d-49ef-8b1c-091f24e8ed12')
# Pillar(start_point=Point(x_coordinate=-21.90013498150996, y_coordinate=21.66764483088971, s_width=0.0, e_width=0.0, b_value=-1.732050807389236), end_point=Point(x_coordinate=-21.90013498150996, y_coordinate=21.66764483088971, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-21.97481884964986, y_coordinate=21.53816414892228, s_width=None, e_width=None, b_value=None), radius=0.15, pillar_id='aefbe418-7458-42cf-a72a-9c4b8a7a7a68')
# Pillar(start_point=Point(x_coordinate=-37.68188903425779, y_coordinate=24.95686692674064, s_width=0.0, e_width=0.0, b_value=-3.884927967661289), end_point=Point(x_coordinate=-37.68188903425779, y_coordinate=24.95686692674064, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-37.57481884964989, y_coordinate=24.78816414892228, s_width=None, e_width=None, b_value=None), radius=0.2, pillar_id='c8e2eb8a-68d2-4510-be26-46d7e4f0e869')
# Pillar(start_point=Point(x_coordinate=-60.81274438009181, y_coordinate=24.9778180904044, s_width=0.0, e_width=0.0, b_value=-1.242158962590891), end_point=Point(x_coordinate=-60.81274438009181, y_coordinate=24.9778180904044, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-60.97481884964986, y_coordinate=24.78816414892222, s_width=None, e_width=None, b_value=None), radius=0.25, pillar_id='670d5fb0-3cc2-4cc4-b1a8-7a031433267f')
# Pillar(start_point=Point(x_coordinate=-68.61603595574299, y_coordinate=40.87864199455507, s_width=0.0, e_width=0.0, b_value=-5.027339490945861), end_point=Point(x_coordinate=-68.61603595574299, y_coordinate=40.87864199455507, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-68.77481884964988, y_coordinate=41.03816414892222, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='5dcb9094-6227-470b-a1ae-2e212517d8c4')
# Pillar(start_point=Point(x_coordinate=-60.97513498150995, y_coordinate=40.81274102032205, s_width=0.0, e_width=0.0, b_value=-2.414213562066414), end_point=Point(x_coordinate=-60.97513498150995, y_coordinate=40.81274102032205, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-60.97481884964986, y_coordinate=41.03816414892222, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='1de46332-7325-41d8-9b02-c42ad75863d3')
# Pillar(start_point=Point(x_coordinate=-53.33423400727689, y_coordinate=40.87864199455511, s_width=0.0, e_width=0.0, b_value=-1.496605762520592), end_point=Point(x_coordinate=-53.33423400727689, y_coordinate=40.87864199455511, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-53.17481884964991, y_coordinate=41.03816414892222, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='d3fe4ecf-1176-4ae9-931e-fd64719203cb')
# Pillar(start_point=Point(x_coordinate=-45.21603595574298, y_coordinate=40.8786419945551, s_width=0.0, e_width=0.0, b_value=-5.027339490947179), end_point=Point(x_coordinate=-45.21603595574298, y_coordinate=40.8786419945551, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-45.3748188496499, y_coordinate=41.03816414892222, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='8606f0f3-aef3-4e65-9f08-37ccbd0671af')
# Pillar(start_point=Point(x_coordinate=-37.73423400727698, y_coordinate=40.87864199455507, s_width=0.0, e_width=0.0, b_value=-1.496605762519715), end_point=Point(x_coordinate=-37.73423400727698, y_coordinate=40.87864199455507, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-37.57481884964989, y_coordinate=41.03816414892228, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='5805b4f2-1daf-4a06-b344-c412be4e4d47')
# Pillar(start_point=Point(x_coordinate=-29.616035955743, y_coordinate=40.87864199455508, s_width=0.0, e_width=0.0, b_value=-5.027339490946556), end_point=Point(x_coordinate=-29.616035955743, y_coordinate=40.87864199455508, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-29.77481884964988, y_coordinate=41.03816414892228, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='5dfad11c-c1b6-4c57-aae4-7c7097052b72')
# Pillar(start_point=Point(x_coordinate=-21.816035955743, y_coordinate=40.87864199455508, s_width=0.0, e_width=0.0, b_value=-5.027339490946316), end_point=Point(x_coordinate=-21.816035955743, y_coordinate=40.87864199455508, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-21.97481884964986, y_coordinate=41.03816414892228, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='c18470f3-aaa9-4e0d-ba5e-29f6c0a65998')
# Pillar(start_point=Point(x_coordinate=-29.77513498150998, y_coordinate=-15.08725897967796, s_width=0.0, e_width=0.0, b_value=-2.414213562066522), end_point=Point(x_coordinate=-29.77513498150998, y_coordinate=-15.08725897967796, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-29.77481884964988, y_coordinate=-14.86183585107773, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='e268393c-641b-4d59-988c-d9c8b5cfe47c')
# Pillar(start_point=Point(x_coordinate=-22.13423400727692, y_coordinate=-15.02135800544491, s_width=0.0, e_width=0.0, b_value=-1.49660576252039), end_point=Point(x_coordinate=-22.13423400727692, y_coordinate=-15.02135800544491, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-21.97481884964986, y_coordinate=-14.86183585107773, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='c3747ac4-49be-4e71-904f-8ff6511a7bed')
# Pillar(start_point=Point(x_coordinate=-14.33423400727693, y_coordinate=-15.02135800544492, s_width=0.0, e_width=0.0, b_value=-1.49660576252025), end_point=Point(x_coordinate=-14.33423400727693, y_coordinate=-15.02135800544492, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-14.17481884964991, y_coordinate=-14.86183585107773, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='41478028-300a-4626-8e4b-096b846b5e46')
# Pillar(start_point=Point(x_coordinate=1.424865018490024, y_coordinate=-15.08725897967796, s_width=0.0, e_width=0.0, b_value=-2.414213562066346), end_point=Point(x_coordinate=1.424865018490024, y_coordinate=-15.08725897967796, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=1.425181150350113, y_coordinate=-14.86183585107773, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='25381c57-f950-4005-a7d6-763b8f557e4c')
# Pillar(start_point=Point(x_coordinate=9.383964044256999, y_coordinate=-15.02135800544493, s_width=0.0, e_width=0.0, b_value=-5.027339490946381), end_point=Point(x_coordinate=9.383964044256999, y_coordinate=-15.02135800544493, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=9.225181150350124, y_coordinate=-14.86183585107773, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='7781b97d-e8b9-4ada-8ddf-0105a8d131b5')
# Pillar(start_point=Point(x_coordinate=17.02486501849003, y_coordinate=-15.08725897967794, s_width=0.0, e_width=0.0, b_value=-2.414213562066589), end_point=Point(x_coordinate=17.02486501849003, y_coordinate=-15.08725897967794, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=17.02518115035008, y_coordinate=-14.86183585107773, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='27512736-2522-403a-a2eb-6e6bbacaa3ea')
# Pillar(start_point=Point(x_coordinate=-6.375134981509987, y_coordinate=-14.63725897967798, s_width=0.0, e_width=0.0, b_value=-2.414213562066859), end_point=Point(x_coordinate=-6.375134981509987, y_coordinate=-14.63725897967798, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-6.374818849649898, y_coordinate=-14.86183585107773, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='cb36f29a-e8db-428b-9f75-e40c7ed8bc16')
# Pillar(start_point=Point(x_coordinate=-89.154350955743, y_coordinate=-20.33909300544491, s_width=0.0, e_width=0.0, b_value=-5.027339490946258), end_point=Point(x_coordinate=-89.154350955743, y_coordinate=-20.33909300544491, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-89.31314177519829, y_coordinate=-20.17957302230766, s_width=None, e_width=None, b_value=None), radius=0.22501, pillar_id='ba9839a5-939c-4296-b8ef-919cf68017a4')
# Pillar(start_point=Point(x_coordinate=-126.96721098151, y_coordinate=-31.00404797967794, s_width=0.0, e_width=0.0, b_value=-0.9999999999999999), end_point=Point(x_coordinate=-126.96721098151, y_coordinate=-31.00404797967794, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-126.7419043262145, y_coordinate=-31.00362196217375, s_width=None, e_width=None, b_value=None), radius=0.22501, pillar_id='ecd57a10-b8b0-470d-b7bb-fda76f59c459')
# Pillar(start_point=Point(x_coordinate=-45.53331800727695, y_coordinate=-14.82275895391097, s_width=0.0, e_width=0.0, b_value=-5.027339490945185), end_point=Point(x_coordinate=-45.53331800727695, y_coordinate=-14.82275895391097, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-45.37390284964988, y_coordinate=-14.98143485107778, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='61961a89-cbe3-401e-8006-d1893ee04cae')
# Pillar(start_point=Point(x_coordinate=-60.94305498150997, y_coordinate=-15.71297497967797, s_width=0.0, e_width=0.0, b_value=-2.414213562066765), end_point=Point(x_coordinate=-60.94305498150997, y_coordinate=-15.71297497967797, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-60.94273884964991, y_coordinate=-15.93755185107779, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='a0e9e19d-1997-4351-9660-2fa90f008760')
# Pillar(start_point=Point(x_coordinate=-68.69816498150995, y_coordinate=-16.54859397967789, s_width=0.0, e_width=0.0, b_value=-2.414213562066213), end_point=Point(x_coordinate=-68.69816498150995, y_coordinate=-16.54859397967789, s_width=0.0, e_width=0.0, b_value=0.0), center_point=Point(x_coordinate=-68.69784884964992, y_coordinate=-16.77317085107779, s_width=None, e_width=None, b_value=None), radius=0.225, pillar_id='282772ee-ada7-4efd-a634-fee0fe46db73')
# Amount of pillars: 66
# Duplicate pilllar matches? False
